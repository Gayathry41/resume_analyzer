# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\GAYATHRI\\Downloads\\long_format_jobs.csv", on_bad_lines='skip')
data.tail()
# Out:
#                Job Title                                    Job Description  \
# 2493  Frontend Developer  Developed single-page applications with Aureli...
# 2494  Frontend Developer  Developed single-page applications with Aureli...
# 2495  Frontend Developer  Developed single-page applications with Aureli...
# 2496  Frontend Developer  Developed single-page applications with Aureli...
# 2497  Frontend Developer  Developed single-page applications with Aureli...
#
#      Category      Value
# 2493    Tools    Aurelia
# 2494    Tools  CSS-in-JS
# 2495    Tools      Axios
# 2496    Tools      QUnit
# 2497    Tools   Mixpanel

# %%
data
# Out:
#                Job Title                                    Job Description  \
# 0      Software Engineer  Triage system issues by identifying their orig...
# 1      Software Engineer  Triage system issues by identifying their orig...
# 2      Software Engineer  Triage system issues by identifying their orig...
# 3      Software Engineer  Triage system issues by identifying their orig...
# 4      Software Engineer  Triage system issues by identifying their orig...
# ...                  ...                                                ...
# 2493  Frontend Developer  Developed single-page applications with Aureli...
# 2494  Frontend Developer  Developed single-page applications with Aureli...
# 2495  Frontend Developer  Developed single-page applications with Aureli...
# 2496  Frontend Developer  Developed single-page applications with Aureli...
# 2497  Frontend Developer  Developed single-page applications with Aureli...
#
#               Category                        Value
# ...
